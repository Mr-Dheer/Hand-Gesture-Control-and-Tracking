# %%
import cv2
import mediapipe
from matplotlib import pyplot as plt
import math

haar_data = cv2.CascadeClassifier(
    './opencv/haarcascades/haarcascade_frontalface_default.xml')

# %%
drawingModule = mediapipe.solutions.drawing_utils
handsModule = mediapipe.solutions.hands


cam = cv2.VideoCapture(0)

with handsModule.Hands(static_image_mode=False, min_detection_confidence=0.7, min_tracking_confidence=0.7, max_num_hands=2) as hands:

    while (True):

        flag, frame = cam.read()
        results = hands.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

        # This will draw the Landmarks on the Screen
        if results.multi_hand_landmarks != None:
            for handLandmarks in results.multi_hand_landmarks:
                drawingModule.draw_landmarks(
                    frame, handLandmarks, handsModule.HAND_CONNECTIONS)

        cv2.imshow('Hand Detection', frame)

        #  If you press Escape the video will Stop
        if cv2.waitKey(1) == 27:
            break

# This is to close the camera
cv2.destroyAllWindows()
cam.release()

# %%
import mediapipe as mp


mediaPipeHands = mp.solutions.hands
utilities = mp.solutions.drawing_utils
hands = mediaPipeHands.Hands()

cam = cv2.VideoCapture(0)

x1, y1, x2, y2 = 0, 0, 0, 0

while True:
    flag, img = cam.read()
    if flag:

        imgConversition = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        results = hands.process(imgConversition)

        if results.multi_hand_landmarks:
            for landmarks in results.multi_hand_landmarks:

                for id, lm, in enumerate(landmarks.landmark):
                    h, w, c = img.shape
                    cx, cy = int(lm.x*w), int(lm.y*h)

                    if (id == 4):
                        cv2.circle(img, (cx, cy), 15,
                                   (255, 255, 0), cv2.FILLED)
                        x1 = cx
                        y1 = cy

                    elif id == 8:
                        cv2.circle(img, (cx, cy), 20,
                                   (255, 255, 0), cv2.FILLED)
                        x2 = cx
                        y2 = cy

                    dist = math.sqrt((x2-x1) ** 2 + (y2-y1) ** 2)
                    print(dist)

                    utilities.draw_landmarks(
                        img, landmarks, mediaPipeHands.HAND_CONNECTIONS)

        cv2.imshow('result', img)
        if cv2.waitKey(2) == 27:
            break
    else:
        print('Camera Not Available')
        break
cv2.destroyAllWindows()
cam.release()
# Out:
# 0.0
# 0.0
# 0.0
# 0.0
# 921.3088515801853
# 921.3088515801853
# 921.3088515801853
# 921.3088515801853
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 203.49447166937975
# 102.7277956543408
# 102.7277956543408
# 102.7277956543408
# 102.7277956543408
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 191.52545522723605
# 128.51459061133875
# 128.51459061133875
# 128.51459061133875
# 128.51459061133875
# ...

# %%
cv2.destroyAllWindows()
cam.release()
